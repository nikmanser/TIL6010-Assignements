# %% [markdown]
# ## General requirements for the assignment
# - Make appropriate comments to your code
# - Use Markdown cells to provide your answers (when applicable)
# - Add your code when there is the comment "YOUR CODE HERE".
# - Stick to Pep8 standard as much as possible for your coding
# - Submit through GitHub
# - Tag the commit as *Final submission of Assignment 1*
# - Post (interesting) errors in the course Github's issue page
#
# ## Assignment Intro
# In this assignment, you will be working with data imports. Data is provided to you both to be downloaded locally and accessed remotely. The final deliverable for the assignment is this ipython notebook with the executed cells active and submitted through your personal GitHub accounts. You will be importing data, conduct some basic data exploration and finally exporting the data and saving it for future use.
#
# You will be working with this data for the other two GO/NOGO assignments as well. The data is from the Google mobility report. You can find more information about this data here: <https://www.google.com/covid19/mobility/data_documentation.html?hl=en>.
#
# ### DEADLINE FOR THIS ASSIGNMENT IS 17 SEPTEMBER 2021 BEFORE 23:59
#
# <hr />

# %% [markdown]
# ## Import libraries
# Update this list as you go along with the assignment

# %%
# YOUR CODE HERE
import pandas as pd
import os
# import libraries

# %% [markdown]
# # PART I - Data Import and Export

# %% [markdown]
# #### 1. Download mobility data from this [link](https://www.google.com/covid19/mobility/), choose *Region CSVs*. From the downloaded data, pick a country to work with. Why did you choose this country?

# %%
# path to the downloaded data folder, e.g. 'Downloads/Region_Mobility_Report_CSVs/'

data_dir = 'C:/Users/nicol/Documents/GitHub/TIL6010-Assignements/Assignments/Assignment 1/' # YOUR CODE HERE
country_code = 'IT' # YOUR CODE HERE

# %% [markdown]
# #### 2. Find the path to the data of your selection. We have prepared some sample code. You need to fill in some parts indicated by 'YOUR CODE HERE'.

# %%
all_files = os.listdir(data_dir)
# initilisation
target_file_name = ''
year = '2020'

for file_name in all_files:
    # check if this file is for 2020
    is_year = year # YOUR CODE HERE
    # if yes, we check if the file name is for the country that you select
    if is_year in file_name:
        # check if the country_code is in the file_name
        is_country = country_code # YOUR CODE HERE
        if is_country in file_name:
            # found the file, save it to 'target_file_name'
            target_file_name = file_name # YOUR CODE HERE
            # we stop looking by breaking out of the for loop
            break
if not target_file_name:
    print('File not found. Check your country code (or select a different one)!')
else:
    print('Found file name is: ' + target_file_name)
    # get the path to the file
    file_path = 'C:/Users/nicol/Documents/GitHub/TIL6010-Assignements/Assignments/Assignment 1/2020_IT_Region_Mobility_Report.csv'# YOUR CODE HERE
    print('Path to the file is: ' + file_path)
# Out:
# Found file name is: 2020_IT_Region_Mobility_Report.csv
# Path to the file is: C:/Users/nicol/Documents/GitHub/TIL6010-Assignements/Assignments/Assignment 1/2020_IT_Region_Mobility_Report.csv

# %% [markdown]
# #### 3. Import the 2020 data for this country as a pandas data frame and name it as `df_2020`. Print the first 10 lines of `df_2020`

# %%
df_2020 = pd.read_csv(file_path)

df_2020.head(10)
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  IT          Italy          NaN          NaN         NaN
# 1                  IT          Italy          NaN          NaN         NaN
# 2                  IT          Italy          NaN          NaN         NaN
# 3                  IT          Italy          NaN          NaN         NaN
# 4                  IT          Italy          NaN          NaN         NaN
# 5                  IT          Italy          NaN          NaN         NaN
# 6                  IT          Italy          NaN          NaN         NaN
# 7                  IT          Italy          NaN          NaN         NaN
# 8                  IT          Italy          NaN          NaN         NaN
# 9                  IT          Italy          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-15
# 1             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-16
# 2             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-17
# 3             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-18
# 4             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-19
# 5             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-20
# 6             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-21
# 7             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-22
# 8             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-23
# 9             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-24
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                3.0
# 1                                                3.0
# 2                                                0.0
# 3                                                3.0
# 4                                                0.0
# 5                                                2.0
# 6                                                1.0
# 7                                               -1.0
# 8                                               -5.0
# 9                                               -4.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               -1.0
# 1                                                2.0
# 2                                                1.0
# 3                                                1.0
# 4                                               -1.0
# 5                                                1.0
# 6                                                1.0
# 7                                                3.0
# 8                                               16.0
# 9                                               23.0
#
#    parks_percent_change_from_baseline  \
# 0                                35.0
# 1                                26.0
# 2                                 7.0
# 3                                16.0
# 4                                11.0
# 5                                18.0
# 6                                19.0
# 7                                30.0
# 8                                23.0
# 9                                22.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            9.0
# 1                                           11.0
# 2                                            3.0
# 3                                            4.0
# 4                                            3.0
# 5                                            5.0
# 6                                            5.0
# 7                                            8.0
# 8                                            6.0
# 9                                          -15.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      0.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
# 5                                      1.0
# 6                                      0.0
# 7                                      0.0
# 8                                      1.0
# 9                                    -14.0
#
#    residential_percent_change_from_baseline
# 0                                      -1.0
# 1                                      -2.0
# 2                                       0.0
# 3                                       0.0
# 4                                       0.0
# 5                                       0.0
# 6                                      -1.0
# 7                                      -1.0
# 8                                       0.0
# 9                                       4.0

# %% [markdown]
# #### We have also stored the data in a remote server. The data for a particular country can be retrieved with the following API:
# `http://mirrors-dev.citg.tudelft.nl:8083/google-mobility-data/{yy}/{CC}`
# #### where yy is either 2020 or 2021, and CC is a 2-letter country code. For example, to get data for 2020 for the Netherlands, the API will be: <http://mirrors-dev.citg.tudelft.nl:8083/google-mobility-data/2020/NL>

# %% [markdown]
# #### 4. Download the mobility report data of **2021** for the same country (that you have chosen above) using this API and name it as `df_2021`.  Print the first 10 lines of the dataframe

# %%
# YOUR CODE HERE
df_2021 = pd.read_csv('http://mirrors-dev.citg.tudelft.nl:8083/google-mobility-data/2021/IT')

print(df_2021.head(10))
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  IT          Italy          NaN          NaN         NaN
# 1                  IT          Italy          NaN          NaN         NaN
# 2                  IT          Italy          NaN          NaN         NaN
# 3                  IT          Italy          NaN          NaN         NaN
# 4                  IT          Italy          NaN          NaN         NaN
# 5                  IT          Italy          NaN          NaN         NaN
# 6                  IT          Italy          NaN          NaN         NaN
# 7                  IT          Italy          NaN          NaN         NaN
# 8                  IT          Italy          NaN          NaN         NaN
# 9                  IT          Italy          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-01
# 1             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-02
# 2             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-03
# 3             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-04
# 4             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-05
# 5             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-06
# 6             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-07
# 7             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-08
# 8             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-09
# 9             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2021-01-10
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                -88
# 1                                                -69
# 2                                                -72
# 3                                                -23
# 4                                                -47
# 5                                                -73
# 6                                                -26
# 7                                                -27
# 8                                                -51
# 9                                                -66
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                -90
# 1                                                -36
# 2                                                -42
# 3                                                 15
# 4                                                  5
# 5                                                -57
# 6                                                  1
# 7                                                  2
# 8                                                -13
# 9                                                -38
#
#    parks_percent_change_from_baseline  \
# 0                               -66.0
# 1                               -66.0
# 2                               -59.0
# 3                               -16.0
# 4                               -45.0
# 5                               -45.0
# 6                               -23.0
# 7                               -17.0
# 8                               -44.0
# 9                               -57.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                          -83.0
# 1                                          -68.0
# 2                                          -62.0
# 3                                          -45.0
# 4                                          -58.0
# 5                                          -73.0
# 6                                          -42.0
# 7                                          -40.0
# 8                                          -50.0
# 9                                          -57.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      -85
# 1                                      -49
# 2                                      -28
# 3                                      -43
# 4                                      -49
# 5                                      -78
# 6                                      -29
# 7                                      -28
# 8                                      -26
# 9                                      -23
#
#    residential_percent_change_from_baseline
# 0                                        31
# 1                                        21
# 2                                        16
# 3                                        15
# 4                                        20
# 5                                        31
# 6                                        13
# 7                                        13
# 8                                        15
# 9                                        15

# %% [markdown]
# #### 5. Combine the two dataframes `df_2020` and `df_2021` into a new dataframe `df`. Print the last 10 lines of `df`.

# %%
# YOUR CODE HERE

frames = [df_2020, df_2021]

df = pd.concat(frames)

df.head(10)
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  IT          Italy          NaN          NaN         NaN
# 1                  IT          Italy          NaN          NaN         NaN
# 2                  IT          Italy          NaN          NaN         NaN
# 3                  IT          Italy          NaN          NaN         NaN
# 4                  IT          Italy          NaN          NaN         NaN
# 5                  IT          Italy          NaN          NaN         NaN
# 6                  IT          Italy          NaN          NaN         NaN
# 7                  IT          Italy          NaN          NaN         NaN
# 8                  IT          Italy          NaN          NaN         NaN
# 9                  IT          Italy          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-15
# 1             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-16
# 2             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-17
# 3             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-18
# 4             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-19
# 5             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-20
# 6             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-21
# 7             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-22
# 8             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-23
# 9             NaN               NaN  ChIJA9KNRIL-1BIRb15jJFz1LOI  2020-02-24
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                3.0
# 1                                                3.0
# 2                                                0.0
# 3                                                3.0
# 4                                                0.0
# 5                                                2.0
# 6                                                1.0
# 7                                               -1.0
# 8                                               -5.0
# 9                                               -4.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               -1.0
# 1                                                2.0
# 2                                                1.0
# 3                                                1.0
# 4                                               -1.0
# 5                                                1.0
# 6                                                1.0
# 7                                                3.0
# 8                                               16.0
# 9                                               23.0
#
#    parks_percent_change_from_baseline  \
# 0                                35.0
# 1                                26.0
# 2                                 7.0
# 3                                16.0
# 4                                11.0
# 5                                18.0
# 6                                19.0
# 7                                30.0
# 8                                23.0
# 9                                22.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            9.0
# 1                                           11.0
# 2                                            3.0
# 3                                            4.0
# 4                                            3.0
# 5                                            5.0
# 6                                            5.0
# 7                                            8.0
# 8                                            6.0
# 9                                          -15.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      0.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
# 5                                      1.0
# 6                                      0.0
# 7                                      0.0
# 8                                      1.0
# 9                                    -14.0
#
#    residential_percent_change_from_baseline
# 0                                      -1.0
# 1                                      -2.0
# 2                                       0.0
# 3                                       0.0
# 4                                       0.0
# 5                                       0.0
# 6                                      -1.0
# 7                                      -1.0
# 8                                       0.0
# 9                                       4.0

# %% [markdown]
# #### 6. `df` now contains mobility data for your selected country from 2020 and 2021. There are three aggregation levels to this data, namely national (`country_region`), provincial (`sub_region_1`), and city (`sub_region_2`). Separate these data into three different dataframes, namely `df_nation`, `df_province`, and `df_city`.  Print the first 5 lines of each of them.
#
# Hint:
# - For the national data, `sub_region_1` and `sub_region_2` are NaN.
# - For the provincial data, `sub_region_2` is NaN.
# - For the city data, `country_region`, `sub_region_1` and `sub_region_2` are not NaN.
# - Logical operators: <https://realpython.com/python-bitwise-operators/>
# - Use pandas [isna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html) function

# %%
# YOUR CODE HERE

df_nation = df['country_region']

df_province = df['sub_region_1']

df_city = df['sub_region_2']

# %%
# YOUR CODE HERE
df_nation.head(5)
# Out:
# 0    Italy
# 1    Italy
# 2    Italy
# 3    Italy
# 4    Italy
# Name: country_region, dtype: object

# %% [markdown]
# #### 7. Save `df_nation`, `df_province`, and `df_city` into csv files under folder 'processed_data', and locate this folder under `data_dir`. Name the files `{CC}_nation.csv`, `{CC}_province.csv`, and `{CC}_city.csv`, respectively. `{CC}` stands for your selected country code.

# %%
# YOUR CODE HERE
df_province.head(5)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: sub_region_1, dtype: object

# %%
# YOUR CODE HERE
df_city.head(5)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: sub_region_2, dtype: object

# %% [markdown]
# <hr />

# %% [markdown]
# # PART II - Simple Data Processing

# %% [markdown]
# #### 1. There are multiple activities in the mobility report such as workplaces, parks, transit stations, etc. For each of the activities, what are the average percent changes from baselines for your selected country?

# %%
# YOUR CODE HERE
recreation_mean = df['retail_and_recreation_percent_change_from_baseline'].mean()

print('%+4.2f' %recreation_mean + ' %')
# Out:
# -23.32 %

# %%
# YOUR CODE HERE
gr_ph_mean = df['grocery_and_pharmacy_percent_change_from_baseline'].mean()

print('%+4.2f' %gr_ph_mean + ' %')
# Out:
# -4.58 %

# %%
# YOUR CODE HERE
parks_mean = df['parks_percent_change_from_baseline'].mean()

print('%+4.2f' %parks_mean + ' %')
# Out:
# +34.78 %

# %%
# YOUR CODE HERE
station_mean = df['transit_stations_percent_change_from_baseline'].mean()

print('%+4.2f' %station_mean + ' %')
# Out:
# -25.03 %

# %%
# YOUR CODE HERE
work_mean = df['workplaces_percent_change_from_baseline'].mean()

print('%+4.2f' %work_mean + ' %')
# Out:
# -25.41 %

# %%
# YOUR CODE HERE
res_mean = df['residential_percent_change_from_baseline'].mean()

print('%+4.2f' %res_mean + ' %')
# Out:
# +8.14 %

# %% [markdown]
# #### 2. Let's look into data from different provinces. How many provinces are there in the data of your selected country? Print all of them.

# %%
# YOUR CODE HERE
set(df['sub_region_1'])
# Out:
# {'Abruzzo',
#  'Aosta',
#  'Apulia',
#  'Basilicata',
#  'Calabria',
#  'Campania',
#  'Emilia-Romagna',
#  'Friuli-Venezia Giulia',
#  'Lazio',
#  'Liguria',
#  'Lombardy',
#  'Marche',
#  'Molise',
#  'Piedmont',
#  'Sardinia',
#  'Sicily',
#  'Trentino-South Tyrol',
#  'Tuscany',
#  'Umbria',
#  'Veneto',
#  nan}

# %% [markdown]
# #### 3. You can get a summary of each of the provinces using pandas describe function. Using this, find which province experienced the largest (average) changes in workplaces.

# %%
# YOUR CODE HERE
df_province['sub_region_1'].describe()
# Out:
# count        71187
# unique          20
# top       Lombardy
# freq          7345
# Name: sub_region_1, dtype: object

# %%
# YOUR CODE HERE
df[df['workplaces_percent_change_from_baseline'] == df['workplaces_percent_change_from_baseline'].max()]
# Out:
#       country_region_code country_region sub_region_1  \
# 27324                  IT          Italy      Tuscany
#
#                         sub_region_2  metro_area iso_3166_2_code  \
# 27324  Province of Massa and Carrara         NaN           IT-MS
#
#        census_fips_code                     place_id        date  \
# 27324               NaN  ChIJmTlARt4e1RIRMIDk45AsCAM  2021-08-29
#
#        retail_and_recreation_percent_change_from_baseline  \
# 27324                                               21.0
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 27324                                               27.0
#
#        parks_percent_change_from_baseline  \
# 27324                               119.0
#
#        transit_stations_percent_change_from_baseline  \
# 27324                                           42.0
#
#        workplaces_percent_change_from_baseline  \
# 27324                                    119.0
#
#        residential_percent_change_from_baseline
# 27324                                      -5.0

# %% [markdown]
# #### 4. Create a new dataframe that only contains data from the province with the largest changes in workplaces, which you found in the previous question.

# %%
# YOUR CODE HERE
df_tuscany = df[df['sub_region_1'] == 'Tuscany']
df_tuscany
# Out:
#       country_region_code country_region sub_region_1       sub_region_2  \
# 33702                  IT          Italy      Tuscany                NaN
# 33703                  IT          Italy      Tuscany                NaN
# 33704                  IT          Italy      Tuscany                NaN
# 33705                  IT          Italy      Tuscany                NaN
# 33706                  IT          Italy      Tuscany                NaN
# ...                   ...            ...          ...                ...
# 28299                  IT          Italy      Tuscany  Province of Siena
# 28300                  IT          Italy      Tuscany  Province of Siena
# 28301                  IT          Italy      Tuscany  Province of Siena
# 28302                  IT          Italy      Tuscany  Province of Siena
# 28303                  IT          Italy      Tuscany  Province of Siena
#
#        metro_area iso_3166_2_code  census_fips_code  \
# 33702         NaN           IT-52               NaN
# 33703         NaN           IT-52               NaN
# 33704         NaN           IT-52               NaN
# 33705         NaN           IT-52               NaN
# 33706         NaN           IT-52               NaN
# ...           ...             ...               ...
# 28299         NaN           IT-SI               NaN
# 28300         NaN           IT-SI               NaN
# 28301         NaN           IT-SI               NaN
# 28302         NaN           IT-SI               NaN
# 28303         NaN           IT-SI               NaN
#
#                           place_id        date  \
# 33702  ChIJezSAEFMr1BIRq1kgW7rDxro  2020-02-15
# 33703  ChIJezSAEFMr1BIRq1kgW7rDxro  2020-02-16
# 33704  ChIJezSAEFMr1BIRq1kgW7rDxro  2020-02-17
# 33705  ChIJezSAEFMr1BIRq1kgW7rDxro  2020-02-18
# 33706  ChIJezSAEFMr1BIRq1kgW7rDxro  2020-02-19
# ...                            ...         ...
# 28299  ChIJddJ5yjp8KRMRoIDk45AsCAM  2021-08-28
# 28300  ChIJddJ5yjp8KRMRoIDk45AsCAM  2021-08-29
# 28301  ChIJddJ5yjp8KRMRoIDk45AsCAM  2021-08-30
# 28302  ChIJddJ5yjp8KRMRoIDk45AsCAM  2021-08-31
# 28303  ChIJddJ5yjp8KRMRoIDk45AsCAM  2021-09-01
#
#        retail_and_recreation_percent_change_from_baseline  \
# 33702                                                5.0
# 33703                                                4.0
# 33704                                                1.0
# 33705                                                2.0
# 33706                                                0.0
# ...                                                  ...
# 28299                                                4.0
# 28300                                               17.0
# 28301                                               17.0
# 28302                                               11.0
# 28303                                               14.0
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 33702                                                0.0
# 33703                                                2.0
# 33704                                                3.0
# 33705                                                1.0
# 33706                                                0.0
# ...                                                  ...
# 28299                                                1.0
# 28300                                                4.0
# 28301                                               20.0
# 28302                                               13.0
# 28303                                               17.0
#
#        parks_percent_change_from_baseline  \
# 33702                                75.0
# 33703                                30.0
# 33704                                 9.0
# 33705                                21.0
# 33706                                 9.0
# ...                                   ...
# 28299                               120.0
# 28300                               121.0
# 28301                               147.0
# 28302                               155.0
# 28303                               124.0
#
#        transit_stations_percent_change_from_baseline  \
# 33702                                           13.0
# 33703                                           11.0
# 33704                                            3.0
# 33705                                            2.0
# 33706                                            0.0
# ...                                              ...
# 28299                                          -16.0
# 28300                                            5.0
# 28301                                          -13.0
# 28302                                          -17.0
# 28303                                          -11.0
#
#        workplaces_percent_change_from_baseline  \
# 33702                                      1.0
# 33703                                      1.0
# 33704                                      1.0
# 33705                                      1.0
# 33706                                      1.0
# ...                                        ...
# 28299                                     -6.0
# 28300                                     29.0
# 28301                                    -19.0
# 28302                                    -20.0
# 28303                                    -18.0
#
#        residential_percent_change_from_baseline
# 33702                                      -2.0
# 33703                                      -2.0
# 33704                                       0.0
# 33705                                       0.0
# 33706                                       0.0
# ...                                         ...
# 28299                                      -1.0
# 28300                                      -5.0
# 28301                                       1.0
# 28302                                       2.0
# 28303                                       2.0
#
# [6215 rows x 15 columns]

# %% [markdown]
# #### 5. We're going to look at the changes of this province over time. As you can see, the column date is in string format. Convert this str date column data str to datetime format and append as an extra column called 'date2' to the dataframe.
# Hint: <https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html>

# %%
# YOUR CODE HERE
date1 = df_tuscany['date']

for date in date1:
    pd.to_datetime(date)
    
date1
# Out:
# 33702    2020-02-15
# 33703    2020-02-16
# 33704    2020-02-17
# 33705    2020-02-18
# 33706    2020-02-19
#             ...
# 28299    2021-08-28
# 28300    2021-08-29
# 28301    2021-08-30
# 28302    2021-08-31
# 28303    2021-09-01
# Name: date, Length: 6215, dtype: object

# %%
dt_form = df_tuscany.assign(date2 = date1)

# %% [markdown]
# #### 6. Sort the data in ascending order of time and save it as 'df_province_largest'

# %%
# YOUR CODE HERE
df_province_largest = dt_form.sort_values(by=['date2'])

df_province_largest
# Out:
#       country_region_code country_region sub_region_1  \
# 33702                  IT          Italy      Tuscany
# 35628                  IT          Italy      Tuscany
# 35307                  IT          Italy      Tuscany
# 36591                  IT          Italy      Tuscany
# 36912                  IT          Italy      Tuscany
# ...                   ...            ...          ...
# 27327                  IT          Italy      Tuscany
# 27571                  IT          Italy      Tuscany
# 27815                  IT          Italy      Tuscany
# 26839                  IT          Italy      Tuscany
# 28303                  IT          Italy      Tuscany
#
#                         sub_region_2  metro_area iso_3166_2_code  \
# 33702                            NaN         NaN           IT-52
# 35628  Province of Massa and Carrara         NaN           IT-MS
# 35307              Province of Lucca         NaN           IT-LU
# 36591              Province of Prato         NaN           IT-PO
# 36912              Province of Siena         NaN           IT-SI
# ...                              ...         ...             ...
# 27327  Province of Massa and Carrara         NaN           IT-MS
# 27571               Province of Pisa         NaN           IT-PI
# 27815            Province of Pistoia         NaN           IT-PT
# 26839            Province of Livorno         NaN           IT-LI
# 28303              Province of Siena         NaN           IT-SI
#
#        census_fips_code                     place_id        date  \
# 33702               NaN  ChIJezSAEFMr1BIRq1kgW7rDxro  2020-02-15
# 35628               NaN  ChIJmTlARt4e1RIRMIDk45AsCAM  2020-02-15
# 35307               NaN  ChIJG8kJnXV61RIRQIDk45AsCAM  2020-02-15
# 36591               NaN  ChIJkSWKskzxKhMRoIPk45AsCAM  2020-02-15
# 36912               NaN  ChIJddJ5yjp8KRMRoIDk45AsCAM  2020-02-15
# ...                 ...                          ...         ...
# 27327               NaN  ChIJmTlARt4e1RIRMIDk45AsCAM  2021-09-01
# 27571               NaN  ChIJp2_X9TsIKhMRgIDk45AsCAM  2021-09-01
# 27815               NaN  ChIJtUMya9-OKhMRUIDk45AsCAM  2021-09-01
# 26839               NaN  ChIJN4QggAU_1hIRcIDk45AsCAM  2021-09-01
# 28303               NaN  ChIJddJ5yjp8KRMRoIDk45AsCAM  2021-09-01
#
#        retail_and_recreation_percent_change_from_baseline  \
# 33702                                                5.0
# 35628                                                5.0
# 35307                                               19.0
# 36591                                                1.0
# 36912                                                6.0
# ...                                                  ...
# 27327                                               19.0
# 27571                                                1.0
# 27815                                                5.0
# 26839                                               52.0
# 28303                                               14.0
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 33702                                                0.0
# 35628                                                0.0
# 35307                                               -1.0
# 36591                                               -1.0
# 36912                                                0.0
# ...                                                  ...
# 27327                                               26.0
# 27571                                               15.0
# 27815                                               12.0
# 26839                                               65.0
# 28303                                               17.0
#
#        parks_percent_change_from_baseline  \
# 33702                                75.0
# 35628                                66.0
# 35307                               100.0
# 36591                                52.0
# 36912                                41.0
# ...                                   ...
# 27327                               162.0
# 27571                                97.0
# 27815                                57.0
# 26839                               469.0
# 28303                               124.0
#
#        transit_stations_percent_change_from_baseline  \
# 33702                                           13.0
# 35628                                            7.0
# 35307                                           29.0
# 36591                                            9.0
# 36912                                            3.0
# ...                                              ...
# 27327                                           -5.0
# 27571                                           -8.0
# 27815                                          -41.0
# 26839                                           99.0
# 28303                                          -11.0
#
#        workplaces_percent_change_from_baseline  \
# 33702                                      1.0
# 35628                                      2.0
# 35307                                      1.0
# 36591                                     -1.0
# 36912                                      3.0
# ...                                        ...
# 27327                                      8.0
# 27571                                    -20.0
# 27815                                    -18.0
# 26839                                      8.0
# 28303                                    -18.0
#
#        residential_percent_change_from_baseline       date2
# 33702                                      -2.0  2020-02-15
# 35628                                      -2.0  2020-02-15
# 35307                                      -2.0  2020-02-15
# 36591                                      -1.0  2020-02-15
# 36912                                      -2.0  2020-02-15
# ...                                         ...         ...
# 27327                                       0.0  2021-09-01
# 27571                                       3.0  2021-09-01
# 27815                                       4.0  2021-09-01
# 26839                                       0.0  2021-09-01
# 28303                                       2.0  2021-09-01
#
# [6215 rows x 16 columns]

# %%
# Execute the cell with the following command to visualize the results
df_province_largest.plot('date', 'workplaces_percent_change_from_baseline')

df_province_largest.resample('7D', on='date2').sum()['workplaces_percent_change_from_baseline'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-0a9f03fb012d> in <module>
#       2 df_province_largest.plot('date', 'workplaces_percent_change_from_baseline')
#       3
# ----> 4 df_province_largest.resample('7D', on='date2').sum()['workplaces_percent_change_from_baseline'].plot()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8367
#    8368         axis = self._get_axis_number(axis)
# -> 8369         return get_resampler(
#    8370             self,
#    8371             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1309     """
#    1310     tg = TimeGrouper(**kwds)
# -> 1311     return tg._get_resampler(obj, kind=kind)
#    1312
#    1313
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1474             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1475
# -> 1476         raise TypeError(
#    1477             "Only valid with DatetimeIndex, "
#    1478             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'

# %% [markdown]
# #### 7. Compare the results above with the results in the google mobility report pdf of your selected province. Discuss the differences and similarities. Please save the mobility report pdf that you use to compare the results with! An example mobility report pdf can be found [here](https://www.gstatic.com/covid19/mobility/2021-09-01_AW_Mobility_Report_en.pdf)
